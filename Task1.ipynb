# %%
import pandas as pd

# %%
taxdata = pd.read_csv('JCT_2013.csv')

# %%
taxdata
# Out:
#                                        Budget_function  \
# 0                                               Energy
# 1                                               Energy
# 2                                               Energy
# 3                                               Energy
# 4                                               Energy
# 5                                               Energy
# 6                                               Energy
# 7                                               Energy
# 8                                               Energy
# 9                                               Energy
# 10                                              Energy
# 11                                              Energy
# 12                                              Energy
# 13                                              Energy
# 14                                              Energy
# 15                                              Energy
# ...

# %%
taxdata.Budget_function.value_counts()
# Out:
# Commerce and housing                                    50
# Energy                                                  47
# Education, training, employment, and social services    38
# Income security                                         19
# Health                                                  14
# International affairs                                   12
# Natural resources and environment                       11
# Community and regional development                      10
# Agriculture                                              7
# Transportation                                           5
# Veterans benefits and services                           4
# Medicare                                                 4
# National Defense                                         4
# General science, space, and technology                   3
# General purpose fiscal assistance                        2
# Social Security                                          1
# ...
